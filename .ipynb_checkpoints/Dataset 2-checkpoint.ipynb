# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import collections

# %%
test_data = pd.read_csv('MultilingualStanceDetection-master\dataset\lepen_fr.csv')

# %%
test_data.head(5)
# Out:
#                    id                                              Tweet  \
# 0  856466484545060865  Non mais c'est une blague?! Holllande qui invi...
# 1  856467386936983552  - La France est divisée entre Alf et une créat...
# 2  856467997891997696  L'humiliation cinglante de Marine Le Pen et du...
# 3  856472563299516416  Le Pen = Bryce\n- trop populaire et c'est inqu...
# 4  856473057426378752  Oubliez pas Le Pen, La grande ANTI-EUROPE, a c...
#
#     Stance   Set     screen_name             user_id                 date  POS
# 0  AGAINST  Test       M2bliquis           556902767  2017-04-24 11:14:56  NaN
# 1  AGAINST  Test  springrevdries  798167193737449472  2017-04-24 11:18:32  NaN
# 2  AGAINST  Test        DcNoemie           586703674  2017-04-24 11:20:57  NaN
# 3  AGAINST  Test        lilouh03          2950062022  2017-04-24 11:39:06  NaN
# 4  AGAINST  Test         Homidmd           511933795  2017-04-24 11:41:04  NaN

# %%
test_label_counts = collections.Counter(test_data['Stance'])
print("Test Data", test_label_counts)
# Out:
# Test Data Counter({'AGAINST': 466, 'FAVOUR': 65, 'NONE': 55})

# %%
test_data = pd.read_csv('MultilingualStanceDetection-master\dataset\macron_fr.csv')
test_data.head(5)
# Out:
#                    id                                              Tweet  \
# 0  856467254384480256  macron il va devenir président alors qu'absolu...
# 1  856477160562974720  lepen/macron au second tour\nla rentrée demain...
# 2  856477308357660672  Le Parti socialiste appelle à voter Macron pou...
# 3  856478118931988480  #Presidentielle2017 : « #Macron a récupéré tou...
# 4  856496320391110656  La #Rotonde #Macron... plus chère que le #Fouq...
#
#     Stance       Set      screen_name     user_id                 date  \
# 0  AGAINST  Training       NOIZU_SAMA   178665231  2017-04-24 11:18:00
# 1     NONE      Test         furax863   314644762  2017-04-24 11:57:22
# 2   FAVOUR  Training      HeelLeClech   543597645  2017-04-24 11:57:57
# 3  AGAINST  Training  Obsequiumamicos  4890037876  2017-04-24 12:01:10
# 4  AGAINST  Training  MarieLaureDupon   119243702  2017-04-24 13:13:30
#
#                                                  POS  \
# ...

# %%
test_label_counts = collections.Counter(test_data['Set'])
print("Test Data", test_label_counts)
# Out:
# Test Data Counter({'Training': 424, 'Test': 106})

# %%
test_label_counts = collections.Counter(test_data['Stance'])
print("Test Data", test_label_counts)
# Out:
# Test Data Counter({'AGAINST': 308, 'NONE': 131, 'FAVOUR': 91})

# %%
test_data = pd.read_csv('MultilingualStanceDetection-master/dataset/referendum_it.csv')
test_data.head(5)
# Out:
#                    id                                              Tweet  \
# 0  801157401437175808  Alla fine si parla di tutto fuorché del merito...
# 1  801891740424736768  Queste due donne non le batte nessuno! #IoVoto...
# 2  799576643178266624  Per chi sia interessato alle ragioni di #IoVot...
# 3  803526945535356929  Leggete e riflettete sulle balle del si\nDomen...
# 4  802827940199362561  Manca solo una settimana al #referendumcostitu...
#
#    Stance       Set    screen_name    user_id                 date  \
# 0   favor  Training      Conrad_MI  414970005  2016-11-22 21:16:23
# 1  agains  Training    luca_vidoni  557827565  2016-11-24 21:54:24
# 2  agains  Training     gigitudine  376310225  2016-11-18 12:35:01
# 3  agains  Training  s_dellavedova  489722273  2016-11-29 10:12:07
# 4  agains      Test       luca97vr  977896784  2016-11-27 11:54:31
#
#                                                  POS  \
# 0  ['Alla\tPRE:det\tal', 'fine\tNOM\tfine', 'si\t...
# ...

# %%
test_label_counts = collections.Counter(test_data['Set'])
print("Test Data", test_label_counts)
# Out:
# Test Data Counter({'Training': 666, 'Test': 167})

# %%
test_label_counts = collections.Counter(test_data['Stance'])
print("Test Data", test_label_counts)
# Out:
# Test Data Counter({'agains': 486, 'none': 184, 'favor': 163})
